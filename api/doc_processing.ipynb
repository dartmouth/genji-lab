# %%
import docx
file_path = "kiritsubo_paragraphs.docx"

# %%
def extract_paragraphs(docx_path):
    # Load the document
    doc = docx.Document(docx_path)
    
    # Extract text from each paragraph
    paragraphs_text = []
    for i, paragraph in enumerate(doc.paragraphs):
        if paragraph.text.strip():  # Skip empty paragraphs
            paragraphs_text.append({f"P{i+1}":paragraph.text})
    
    return paragraphs_text

# %%
text = extract_paragraphs(file_path)
print(text[0])
# Out:
# {'P1': 'IN WHOSE reign was it that a woman of rather undistinguished lineage captured the heart of the Emperor and enjoyed his favor above all the other imperial wives and concubines? Certain consorts, whose high noble status gave them a sense of vain entitlement, despised and reviled her as an unworthy upstart from the very moment she began her service. Ladies of lower rank were even more vexed, for they knew His Majesty would never bestow the same degree of affection and attention on them. As a result, the mere presence of this woman at morning rites or evening ceremonies seemed to provoke hostile reactions among her rivals, and the anxiety she suffered as a consequence of these ever-increasing displays of jealousy was such a heavy burden that gradually her health began to fail. [link to original paragraph 1.1]'}

# %%
def process_paragraphs_with_links_string_based(paragraphs_data):
    """
    Process paragraphs with links using string operations instead of regex.
    """
    processed_dict = {}
    
    for para_dict in paragraphs_ para_id, text in para_dict.items():
            links = []
            clean_text = text
            
            # Look for the characteristic beginning of the link
            link_marker = "[link to original paragraph"
            if link_marker in text:
                # Find the position of the link
                start_idx = text.rfind(link_marker)
                
                # Extract the link part
                link_part = text[start_idx:]
                
                # Clean the text by removing the link
                clean_text = text[:start_idx].strip()
                
                # Extract section and paragraph numbers
                try:
                    # Extract the numbers part (e.g., "1.1")
                    numbers_part = link_part.split("paragraph")[1].split("]")[0].strip()
                    section_str, paragraph_str = numbers_part.split(".")
                    
                    link_info = {
                        'text_collection': "original",
                        'section': int(section_str),
                        'paragraph': int(paragraph_str)
                    }
                    
                    links.append(link_info)
                    print(f"Found link in {para_id}: Section {link_info['section']}, Paragraph {link_info['paragraph']}")
                except Exception as e:
                    print(f"Error parsing link in {para_id}: {e}")
            
            processed_dict[para_id] = {
                'text': clean_text,
                'links': links
            }
    
    return processed_dict

# %%
processed_data = process_paragraphs_with_links(text)
print(processed_data['P1'])
# Out:
# No link found in P1
# Text ending: 'th began to fail. [link to original paragraph 1.1]'
# No link found in P3
# Text ending: 'racious devotion. [link to original paragraph 1.1]'
# No link found in P5
# Text ending: 'ertain prospects. [link to original paragraph 1.2]'
# No link found in P8
# Text ending: 'ed a rare beauty. [link to original paragraph 1.3]'
# No link found in P10
# Text ending: 'tention upon him. [link to original paragraph 1.3]'
# No link found in P12
# Text ending: 'the Crown Prince. [link to original paragraph 1.4]'
# No link found in P14
# Text ending: 'ause of his love. [link to original paragraph 1.4]'
# No link found in P16
# Text ending: 'sible to placate. [link to original paragraph 1.5]'
# No link found in P18
# Text ending: ' into this world. [link to original paragraph 1.6]'
# No link found in P20
# Text ending: 'young son behind. [link to original paragraph 1.7]'
# No link found in P22
# Text ending: 'lf to let her go. [link to original paragraph 1.8]'
# No link found in P24
# Text ending: 'don me,” he said. [link to original paragraph 1.8]'
# No link found in P26
# Text ending: 'lty, she still managed to compose a verse for him:'
# No link found in P28
# Text ending: 'Now in deepest sorrow as I contemplate'
# No link found in P29
# Text ending: 'Our diverging roads, this fork where we must part'
# No link found in P30
# Text ending: 'How I long to walk the path of the living'
# No link found in P32
# Text ending: 'ut like this ...” [link to original paragraph 1.8]'
# No link found in P34
# Text ending: 'ke that decision. [link to original paragraph 1.8]'
# No link found in P36
# Text ending: ' dark foreboding. [link to original paragraph 1.9]'
# No link found in P38
# Text ending: 'est of the court. [link to original paragraph 1.9]'
# No link found in P40
# Text ending: 'dness of it all. [link to original paragraph 1.10]'
# No link found in P42
# Text ending: 'y was performed. [link to original paragraph 1.11]'
# No link found in P44
# Text ending: 'to her passing.” [link to original paragraph 1.11]'
# No link found in P46
# Text ending: 't to do for her. [link to original paragraph 1.11]'
# No link found in P48
# Text ending: 'ow of affection. [link to original paragraph 1.12]'
# No link found in P50
# Text ending: ' yearn for her.” [link to original paragraph 1.13]'
# No link found in P52
# Text ending: ' a dew of tears. [link to original paragraph 1.14]'
# No link found in P54
# Text ending: 'e after the boy. [link to original paragraph 1.14]'
# No link found in P56
# Text ending: 'nce was staying. [link to original paragraph 1.15]'
# No link found in P58
# Text ending: 'ere in the dark. [link to original paragraph 1.15]'
# No link found in P60
# Text ending: ' wild profusion. [link to original paragraph 1.16]'
# No link found in P62
# Text ending: 'ntrol her grief. [link to original paragraph 1.17]'
# No link found in P64
# Text ending: 'nally sensitive, I now understand what she meant.”'
# No link found in P65
# Text ending: 'or had given her: [link to original paragraph 1.17'
# No link found in P67
# Text ending: 'n dew and tears. [link to original paragraph 1.18]'
# No link found in P69
# Text ending: 'ing he told me.” [link to original paragraph 1.18]'
# No link found in P71
# Text ending: 'ked at the note: [link to original paragraph 1.19]'
# No link found in P73
# Text ending: ' my former love. [link to original paragraph 1.19]'
# No link found in P75
# Text ending: 'elings in the letter. He had even attached a poem:'
# No link found in P77
# Text ending: 'Winds rustle the bush clover at Miyagino'
# No link found in P78
# Text ending: ' dew to pearls ... winds at the palace bring tears'
# No link found in P79
# Text ending: 'ver at your home [link to original paragraph 1.19]'
# No link found in P81
# Text ending: 'ke me deserves.” [link to original paragraph 1.20]'
# No link found in P83
# Text ending: 'd I must leave.” [link to original paragraph 1.21]'
# No link found in P85
# Text ending: 'w well advanced. [link to original paragraph 1.22]'
# No link found in P87
# Text ending: 'ng and heard him say the following over and over”:'
# No link found in P89
# Text ending: 'to deserve this? [link to original paragraph 1.23]'
# No link found in P91
# Text ending: 'k to the palace. [link to original paragraph 1.23]'
# No link found in P93
# Text ending: ' desolate abode. [link to original paragraph 1.24]'
# No link found in P95
# Text ending: 'Bell crickets seem to cry their hearts out'
# No link found in P96
# Text ending: 'But the tears I weep are not confined'
# No link found in P97
# Text ending: 'To a single long night in autumn'
# No link found in P99
# Text ending: 'his may perhaps sound like an accusation, but ...”'
# No link found in P101
# Text ending: 'A caller from beyond the clouds brings dewy tears'
# No link found in P102
# Text ending: 'And greater woe to this hut amidst tangled reeds'
# No link found in P103
# Text ending: 'ring of crickets [link to original paragraph 1.24]'
# No link found in P105
# Text ending: 'is very purpose. [link to original paragraph 1.25]'
# No link found in P107
# Text ending: 'o send him away. [link to original paragraph 1.26]'
# No link found in P109
# Text ending: 'd to talk about. [link to original paragraph 1.27]'
# No link found in P111
# Text ending: ' to his request: [link to original paragraph 1.27]'
# No link found in P113
# Text ending: 'words throw my troubled heart into dark confusion.'
# No link found in P115
# Text ending: 'The tree that was once a buffer against'
# No link found in P116
# Text ending: 'These harsh autumn winds has withered and left'
# No link found in P117
# Text ending: 's uncertain fate [link to original paragraph 1.27]'
# No link found in P119
# Text ending: 'briefest period. [link to original paragraph 1.28]'
# No link found in P121
# Text ending: 'lorious future.” [link to original paragraph 1.29]'
# No link found in P123
# Text ending: 'ceased love. But he knew these were idle thoughts.'
# No link found in P125
# Text ending: 'Had I sent a Taoist summoner'
# No link found in P126
# Text ending: 'To seek the spirit of my beloved'
# No link found in P127
# Text ending: 'd where she went [link to original paragraph 1.30]'
# No link found in P129
# Text ending: 'ancholy regrets. [link to original paragraph 1.31]'
# No link found in P131
# Text ending: 'Majesty’s grief. [link to original paragraph 1.32]'
# No link found in P133
# Text ending: 'The moon was waning.'
# No link found in P135
# Text ending: 'If even at the palace above the clouds'
# No link found in P136
# Text ending: 'A mist of tears can obscure the autumn moon'
# No link found in P137
# Text ending: ' that rustic hut [link to original paragraph 1.32]'
# No link found in P139
# Text ending: ' been drawn up.” [link to original paragraph 1.33]'
# No link found in P141
# Text ending: 'd the example of Emperor Xuanzong and Yang Guifei.'
# No link found in P142
# Text ending: '[link to original paragraph 1.33]'
# No link found in P144
# Text ending: 'an unlucky omen. [link to original paragraph 1.34]'
# No link found in P146
# Text ending: 'nd satisfaction. [link to original paragraph 1.34]'
# No link found in P148
# Text ending: 'ne in the world. [link to original paragraph 1.35]'
# No link found in P150
# Text ending: 'ties with alarm. [link to original paragraph 1.36]'
# No link found in P152
# Text ending: 'with affection.” [link to original paragraph 1.36]'
# No link found in P154
# Text ending: 'ecial deference. [link to original paragraph 1.36]'
# No link found in P156
# Text ending: 'good to be true. [link to original paragraph 1.37]'
# No link found in P158
# Text ending: 'ontroller’s son. [link to original paragraph 1.38]'
# No link found in P160
# Text ending: 'ms less likely.” [link to original paragraph 1.38]'
# No link found in P162
# Text ending: 'grew suspicious. [link to original paragraph 1.39]'
# No link found in P164
# Text ending: ' him a commoner. [link to original paragraph 1.40]'
# No link found in P166
# Text ending: 'ionally see her. [link to original paragraph 1.41]'
# No link found in P168
# Text ending: 'ent and beauty.” [link to original paragraph 1.41]'
# No link found in P170
# Text ending: 'creet inquiries. [link to original paragraph 1.41]'
# No link found in P172
# Text ending: 'she passed away. [link to original paragraph 1.42]'
# No link found in P174
# Text ending: 'd circumstances. [link to original paragraph 1.42]'
# No link found in P176
# Text ending: 'rt to his heart. [link to original paragraph 1.42]'
# No link found in P178
# Text ending: 'r’s new consort! [link to original paragraph 1.43]'
# No link found in P180
# Text ending: 'he way he does.” [link to original paragraph 1.44]'
# No link found in P182
# Text ending: 'he Radiant Sun.” [link to original paragraph 1.44]'
# No link found in P184
# Text ending: 'utmost splendor. [link to original paragraph 1.45]'
# No link found in P186
# Text ending: 'n his composure. [link to original paragraph 1.45]'
# No link found in P188
# Text ending: 'asculine beauty. [link to original paragraph 1.46]'
# No link found in P190
# Text ending: 'th his proposal. [link to original paragraph 1.47]'
# No link found in P192
# Text ending: ' with his plans. [link to original paragraph 1.47]'
# No link found in P194
# Text ending: 'did not respond. [link to original paragraph 1.48]'
# No link found in P196
# Text ending: 'es toward Genji: [link to original paragraph 1.49]'
# No link found in P198
# Text ending: 'When you with purple cords first bound his hair'
# No link found in P199
# Text ending: 'Did you not also bind your heart and swear'
# No link found in P200
# Text ending: 'Eternal vows to give him your daughter'
# No link found in P202
# Text ending: 'The Minister composed this reply:'
# No link found in P204
# Text ending: 'o long as the deep purple of these cords that bind'
# No link found in P205
# Text ending: 'ur hearts as tightly as your son’s hair never fade'
# No link found in P206
# Text ending: 'ain its deep hue [link to original paragraph 1.49]'
# No link found in P208
# Text ending: 'e to their rank. [link to original paragraph 1.49]'
# No link found in P210
# Text ending: 'nificent affair. [link to original paragraph 1.49]'
# No link found in P212
# Text ending: 'h inappropriate. [link to original paragraph 1.50]'
# No link found in P214
# Text ending: 'deal friendship. [link to original paragraph 1.51]'
# No link found in P216
# Text ending: 'him every favor. [link to original paragraph 1.52]'
# No link found in P218
# Text ending: 'oman, Fujitsubo. [link to original paragraph 1.53]'
# No link found in P220
# Text ending: ' Radiant Prince. [link to original paragraph 1.54]'
# {'text': 'IN WHOSE reign was it that a woman of rather undistinguished lineage captured the heart of the Emperor and enjoyed his favor above all the other imperial wives and concubines? Certain consorts, whose high noble status gave them a sense of vain entitlement, despised and reviled her as an unworthy upstart from the very moment she began her service. Ladies of lower rank were even more vexed, for they knew His Majesty would never bestow the same degree of affection and attention on them. As a result, the mere presence of this woman at morning rites or evening ceremonies seemed to provoke hostile reactions among her rivals, and the anxiety she suffered as a consequence of these ever-increasing displays of jealousy was such a heavy burden that gradually her health began to fail. [link to original paragraph 1.1]', 'links': []}

# %%
for _, entry in processed_data.items():
    print(entry['links'])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
